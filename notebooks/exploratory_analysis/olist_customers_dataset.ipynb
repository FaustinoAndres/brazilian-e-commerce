# %% [markdown]
# ### Initial exploratory analysis of the olist_customers_dataset.csv table set

# %%
# Import libraries here
# Tool that allows us to import, better manage the data set
import pandas as pd
# Tool that helps us in the mathematical handling of data
import numpy as np
# Library that helps us in data visualization
import matplotlib.pyplot as plt
# Data visualization tool
import seaborn as sns
sns.set_theme(style="darkgrid")
sns.set(rc={'figure.figsize':(15,8.27)})

# %%
# Import data here
df = pd.read_csv('../../data/raw/olist_customers_dataset.csv')

# %%
# The method is used to display the first rows of the dataframe
df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
# At this point we visualize the data of the last rows of the dataframe
df.tail()
# Out:
#                             customer_id                customer_unique_id  \
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix    customer_city customer_state
# 99436                      3937        sao paulo             SP
# 99437                      6764  taboao da serra             SP
# 99438                     60115        fortaleza             CE
# 99439                     92120           canoas             RS
# 99440                      6703            cotia             SP

# %%
# Check the number of rows and columns of the dataframe
print(df.shape)
# Out:
# (99441, 5)

# %%
# We extend information of my dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
df.dtypes
# Out:
# customer_id                 object
# customer_unique_id          object
# customer_zip_code_prefix     int64
# customer_city               object
# customer_state              object
# dtype: object

# %% [markdown]
# - We can see that we have within our data set a column with integer data and the other 4 with object or categorical data.

# %%
df.describe()
# Out:
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %% [markdown]
# - It can be seen that there are 99441 tuples by count and it coincides with the number of elements that exist with respect to the customer_zip_code_prefix column

# %% [markdown]
# If we proceed to generate the descriptive information of the entire data set, it can give us an overview of the other columns, because with the describe() function, it allows us to give the characteristics of the columns with numerical data, we know that the other columns have data of other characteristics for this reason we will use the function describe(include='all') and in this way obtain more information

# %%
df.describe(include='all')
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# ...

# %% [markdown]
# - With the recent description of the data we can see that the customer_id column has 99441 unique records that guarantees that the identification of the tuples is unique and they are not repeated, for this reason we do not have tuples with the same identification.
# - Regarding the customer_unique_id column of the 99441 tuples, we have 96096 with a unique value, giving as a consequence that we have data whose identification of the customer_unique_id coincides for the information referring to the other columns.
# - Regarding the customer_city column, we have 4119 unique records within our table, whose top or most repeated value is 'sao paulo'.
# - In relation to the customer_state column we have 27 unique values whose most repeated value is 'SP'.

# %% [markdown]
# We will proceed to evaluate if within our data set we have null data or NaN and thus be able to know where.

# %%
df.isnull().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %% [markdown]
# With regard to having null data, it tells us that we do not have null data in our data set

# %%
df['customer_unique_id'].value_counts()
# Out:
# 8d50f5eadf50201ccdcedfb9e2ac8455    17
# 3e43e6105506432c953e165fb2acf44c     9
# 1b6c7548a2a1f9037c1fd3ddfed95f33     7
# ca77025e7201e3b30c44b472ff346268     7
# 6469f99c1f9dfae7733b25662e7f1782     7
#                                     ..
# 081f07439678af2da7755a0aa572154d     1
# 9c57789a6a587f4efcfb01e36c106014     1
# 9e4c21635f640562de1a6976374fba03     1
# 06c0ea6ee892364d1608ee47aa9f56a0     1
# 84732c5050c01db9b23e19ba39899398     1
# Name: customer_unique_id, Length: 96096, dtype: int64

# %%
df.groupby('customer_unique_id').count()
# Out:
#                                   customer_id  customer_zip_code_prefix  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2            1                         1
# 0000b849f77a49e4a4ce2b2a4ca5be3f            1                         1
# 0000f46a3911fa3c0805444483337064            1                         1
# 0000f6ccb0745a6a4b88665a16c9f078            1                         1
# 0004aac84e0df4da2b147fca70cf8255            1                         1
# ...                                       ...                       ...
# fffcf5a5ff07b0908bd4e2dbc735a684            1                         1
# fffea47cd6d3cc0a88bd621562a9d061            1                         1
# ffff371b4d645b6ecea244b27531430a            1                         1
# ffff5962728ec6157033ef9805bacc48            1                         1
# ffffd2657e2aad2907e67c3e9daecbeb            1                         1
#
#                                   customer_city  customer_state
# ...

# %%
#sns.countplot(x='customer_unique_id', data=df)

# %% [markdown]
# - Referring to the 'customer_unique_id' column, we can see that the value that is repeated the most does so 17 times, followed by 9 and another 7, which complements the unique data in the column

# %%
df['customer_zip_code_prefix'].value_counts()
# Out:
# 22790    142
# 24220    124
# 22793    121
# 24230    117
# 22775    110
#         ...
# 35698      1
# 99370      1
# 64808      1
# 60876      1
# 99043      1
# Name: customer_zip_code_prefix, Length: 14994, dtype: int64

# %%
df.groupby('customer_zip_code_prefix').count()
# Out:
#                           customer_id  customer_unique_id  customer_city  \
# customer_zip_code_prefix
# 1003                                1                   1              1
# 1004                                2                   2              2
# 1005                                6                   6              6
# 1006                                2                   2              2
# 1007                                4                   4              4
# ...                               ...                 ...            ...
# 99960                               2                   2              2
# 99965                               2                   2              2
# 99970                               1                   1              1
# 99980                               2                   2              2
# 99990                               1                   1              1
#
#                           customer_state
# ...

# %%
#sns.countplot(x='customer_zip_code_prefix', data=df)

# %% [markdown]
# - We can see in the 'customer zip code prefix' column, whose data is repeated the most, it does so 142 times and is thus distributed until reaching the unique values

# %%
df['customer_city'].value_counts()
# Out:
# sao paulo            15540
# rio de janeiro        6882
# belo horizonte        2773
# brasilia              2131
# curitiba              1521
#                      ...
# bequimao                 1
# andarai                  1
# vargem grande            1
# curvelandia              1
# eugenio de castro        1
# Name: customer_city, Length: 4119, dtype: int64

# %%
df.groupby('customer_city').count()
# Out:
#                      customer_id  customer_unique_id  \
# customer_city
# abadia dos dourados            3                   3
# abadiania                      1                   1
# abaete                        12                  12
# abaetetuba                    11                  11
# abaiara                        2                   2
# ...                          ...                 ...
# xinguara                       9                   9
# xique-xique                    3                   3
# zacarias                       2                   2
# ze doca                        5                   5
# zortea                         2                   2
#
#                      customer_zip_code_prefix  customer_state
# customer_city
# abadia dos dourados                         3               3
# abadiania                                   1               1
# abaete                                     12              12
# ...

# %%
#sns.countplot(x='customer_city', data=df)

# %% [markdown]
# - To complement the exploration of the 'customer_city' column, we can verify that after Sao Paulo, the other 4 cities that have a greater number of appearances in our tuples within the data set are Rio de Janeiro, Belo Horizonte, Brasilia and curitiba respectively.

# %%
df['customer_state'].value_counts()
# Out:
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: customer_state, dtype: int64

# %%
df.groupby('customer_state').count()
# Out:
#                 customer_id  customer_unique_id  customer_zip_code_prefix  \
# customer_state
# AC                       81                  81                        81
# AL                      413                 413                       413
# AM                      148                 148                       148
# AP                       68                  68                        68
# BA                     3380                3380                      3380
# CE                     1336                1336                      1336
# DF                     2140                2140                      2140
# ES                     2033                2033                      2033
# GO                     2020                2020                      2020
# MA                      747                 747                       747
# MG                    11635               11635                     11635
# ...

# %%
sns.countplot(y='customer_state', data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='customer_state'>

# %% [markdown]
# - Regarding the 'customer_state' column, we can verify that there are 27 categories and this makes sense since Brazil has 26 States and the Federal District, we also see that the distribution for each of the states.
