# %% [markdown]
# ### Initial exploratory analysis of the olist_orders_dataset.csv table set

# %%
# Import libraries here
# Tool that allows us to import, better manage the data set
import pandas as pd
# Tool that helps us in the mathematical handling of data
import numpy as np
# Library that helps us in data visualization
import matplotlib.pyplot as plt
# Data visualization tool
import seaborn as sns
sns.set_theme(style="darkgrid")
sns.set(rc={'figure.figsize':(15,8.27)})

# %%
# Import data here
df = pd.read_csv("../../data/raw/olist_orders_dataset.csv")

# %%
# The method is used to display the first rows of the dataframe
df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
# At this point we visualize the data of the last rows of the dataframe.
df.tail()
# Out:
#                                order_id                       customer_id  \
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# 99436    delivered      2017-03-09 09:54:05  2017-03-09 09:54:05
# 99437    delivered      2018-02-06 12:58:58  2018-02-06 13:10:37
# 99438    delivered      2017-08-27 14:46:43  2017-08-27 15:04:16
# 99439    delivered      2018-01-08 21:28:27  2018-01-08 21:36:21
# 99440    delivered      2018-03-08 20:57:30  2018-03-09 11:20:28
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# ...

# %%
# Check the number of rows and columns of the dataframe
print(df.shape)
# Out:
# (99441, 8)

# %%
# We extensive information on my dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
df.dtypes
# Out:
# order_id                         object
# customer_id                      object
# order_status                     object
# order_purchase_timestamp         object
# order_approved_at                object
# order_delivered_carrier_date     object
# order_delivered_customer_date    object
# order_estimated_delivery_date    object
# dtype: object

# %% [markdown]
# - Within this data set we have all the columns with information of the object type, that is, they are data with categorical information.
# - Of which the columns 'order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date' and 'order_estimated_delivery_date' are columns that refer to dates and times.
# - The 'order_id' and 'customer_id' columns are columns with identifier information.
# - Regarding the 'order_status' column, it refers to the status of the order, for this reason it is information that makes sense, whether it is categorical information.

# %% [markdown]
# Due to the fact that our data set has data of type object, we must use the describe(include='all') function, in order to have a greater amount of preliminary information about the data set and to be able to have the descriptive statistics of our data set.

# %%
df.describe(include='all')
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99281
# unique            8                    98875                90733
# top       delivered      2018-04-11 10:48:14  2018-02-27 04:31:10
# freq          96478                        3                    9
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        81018                         95664
# ...

# %% [markdown]
# - Regarding the 'order_id' column of the 99441 records it has the same amount of unique data.
# - In addition, the 'customer_id' column has the same characteristics as the previous column since the same number of records has the same number of unique values.
# - Regarding the 'order_status' column, it has 8 unique values ​​whose most repeated value is 'delivered', which does so with a frequency of 96378 times.
# - The date column 'order_purchase_timestamp' has 98875 unique values ​​out of 99441 that represent all the tuples in the dataset having a date that is repeated 3 times.
# - The date column 'order_approved_at' has a smaller number of records compared to the number of tuples with valid values, having 97658 of which 81018 values ​​are unique, it can also be said that it has a date that is repeated 47 times, this being the one of higher frequency.
# - The 'order_delivered_customer_date' column passes the same as the previous column because it has a number of valid records less than the number of rows within the data set, which represents 96476 values, of which 95664 values ​​are unique, having a date as value top whose frequency within the set is 3 repetitions.
# - Regarding the last column 'order_estimated_delivery_date' we can say that it has 459 unique values ​​and has the top value of a date whose frequency level within the data set is 522 times.

# %% [markdown]
# We will proceed to evaluate if within our data set we have null data or NaN and thus be able to know where.

# %%
df.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %% [markdown]
# - Just as we previously had an initial idea of the data by being able to see its descriptive statistics, we can observe the 3 columns with NaN data, not being a high amount of data compared to the number of rows that the set has.

# %%
df['order_id'].value_counts()
# Out:
# e481f51cbdc54678b7cc49136f2d6af7    1
# f01059d0d674e1282df4e8fbbe015aa2    1
# fbc17f0f2a2125054d5ac5c22d2d5120    1
# 9373150545066777b1cd2bc20e93cf8e    1
# 917399e96f92268dfa2c0351b1b75fba    1
#                                    ..
# 6b8986012d61963295ffa3ea869aff86    1
# be879f757debd3b384b540daa6ddd97e    1
# ac3ce7eda1246f39509a505242fcc169    1
# e801a93b3904ca9e8350f176a037047b    1
# 66dea50a8b16d9b4dee7af250b4be1a5    1
# Name: order_id, Length: 99441, dtype: int64

# %%
df.groupby('order_id').count()
# Out:
#                                   customer_id  order_status  \
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214            1             1
# 00018f77f2f0320c557190d7a144bdd3            1             1
# 000229ec398224ef6ca0657da4fc703e            1             1
# 00024acbcdf0a6daa1e931b038114c75            1             1
# 00042b26cf59d7ce69dfabb4e55b4fd9            1             1
# ...                                       ...           ...
# fffc94f6ce00a00581880bf54a75a037            1             1
# fffcd46ef2263f404302a634eb57f7eb            1             1
# fffce4705a9662cd70adb13d4a31832d            1             1
# fffe18544ffabc95dfada21779c9644f            1             1
# fffe41c64501cc87c801fd61db3f6244            1             1
#
#                                   order_purchase_timestamp  order_approved_at  \
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214                         1                  1
# ...

# %% [markdown]
# - As we had previously visualized the unique data, we will not have repeated data to be able to count how many there are for each one.

# %%
df['customer_id'].value_counts()
# Out:
# 9ef432eb6251297304e76186b10a928d    1
# 413f7e58270a32396af030a075b924be    1
# eb4350b67a0264c67e5e06a038e4afbb    1
# 622b07d262d545d16efbd4363a89cb91    1
# c701fbfa77791abd05eef9eacf7ea7a8    1
#                                    ..
# 39585f08d13377e50fde35467984e6eb    1
# eb3d995301c320683de629f5b4dd0c78    1
# f2507ea56d748a23037bb1214964e87d    1
# ae8269d850cd3a3d06a56877c450b3f8    1
# edb027a75a1449115f6b43211ae02a24    1
# Name: customer_id, Length: 99441, dtype: int64

# %%
df.groupby('customer_id').count()
# Out:
#                                   order_id  order_status  \
# customer_id
# 00012a2ce6f8dcda20d059ce98491703         1             1
# 000161a058600d5901f007fab4c27140         1             1
# 0001fd6190edaaf884bcaf3d49edf079         1             1
# 0002414f95344307404f0ace7a26f1d5         1             1
# 000379cdec625522490c315e70c7a9fb         1             1
# ...                                    ...           ...
# fffecc9f79fd8c764f843e9951b11341         1             1
# fffeda5b6d849fbd39689bb92087f431         1             1
# ffff42319e9b2d713724ae527742af25         1             1
# ffffa3172527f765de70084a7e53aae8         1             1
# ffffe8b65bbe3087b653a978c870db99         1             1
#
#                                   order_purchase_timestamp  order_approved_at  \
# customer_id
# 00012a2ce6f8dcda20d059ce98491703                         1                  1
# 000161a058600d5901f007fab4c27140                         1                  1
# ...

# %% [markdown]
# - In the same way as the evaluation of the previous column, it can be determined that it has unique data within its entire set and we could not add the quantities for each group since they are values that only appear for each tuple within the data set.

# %%
df['order_status'].value_counts()
# Out:
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: order_status, dtype: int64

# %%
df.groupby('order_status').count()
# Out:
#               order_id  customer_id  order_purchase_timestamp  \
# order_status
# approved             2            2                         2
# canceled           625          625                       625
# created              5            5                         5
# delivered        96478        96478                     96478
# invoiced           314          314                       314
# processing         301          301                       301
# shipped           1107         1107                      1107
# unavailable        609          609                       609
#
#               order_approved_at  order_delivered_carrier_date  \
# order_status
# approved                      2                             0
# canceled                    484                            75
# created                       0                             0
# delivered                 96464                         96476
# invoiced                    314                             0
# ...

# %%
sns.countplot(y='order_status', data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='order_status'>

# %% [markdown]
# - Within the 'order_status' column there are 8 categories in which it gives us reference to the registration of orders and generates the hypothesis by the names that it is the sample of a workflow since there are categories that are found in lower values as they are 'approved' until reaching the most frequently which is 'deliverd' with the most significant number.

# %%
df['order_purchase_timestamp'].value_counts()
# Out:
# 2018-04-11 10:48:14    3
# 2018-07-28 13:11:22    3
# 2017-11-20 10:59:08    3
# 2018-08-02 12:05:26    3
# 2018-08-02 12:06:09    3
#                       ..
# 2018-07-14 19:23:47    1
# 2018-05-10 16:08:05    1
# 2017-11-28 10:46:46    1
# 2018-03-17 23:46:08    1
# 2018-03-08 20:57:30    1
# Name: order_purchase_timestamp, Length: 98875, dtype: int64

# %%
df.groupby('order_purchase_timestamp').count()
# Out:
#                           order_id  customer_id  order_status  \
# order_purchase_timestamp
# 2016-09-04 21:15:19              1            1             1
# 2016-09-05 00:15:34              1            1             1
# 2016-09-13 15:24:19              1            1             1
# 2016-09-15 12:16:38              1            1             1
# 2016-10-02 22:07:52              1            1             1
# ...                            ...          ...           ...
# 2018-09-29 09:13:03              1            1             1
# 2018-10-01 15:30:09              1            1             1
# 2018-10-03 18:55:29              1            1             1
# 2018-10-16 20:16:02              1            1             1
# 2018-10-17 17:30:18              1            1             1
#
#                           order_approved_at  order_delivered_carrier_date  \
# order_purchase_timestamp
# 2016-09-04 21:15:19                       1                             1
# ...

# %% [markdown]
# - It can be seen in the 'order purchase timestamp' column that there is an amount of data that repeats the dates 3 times and other unique records within the data set.

# %%
df['order_approved_at'].value_counts()
# Out:
# 2018-02-27 04:31:10    9
# 2017-11-07 07:30:38    7
# 2018-02-27 04:31:01    7
# 2018-02-06 05:31:52    7
# 2017-11-07 07:30:29    7
#                       ..
# 2018-08-22 11:50:14    1
# 2017-09-22 11:27:36    1
# 2018-03-07 16:40:32    1
# 2017-08-08 10:50:15    1
# 2018-03-09 11:20:28    1
# Name: order_approved_at, Length: 90733, dtype: int64

# %%
df['order_approved_at'].isnull().sum()
# Out:
# 160

# %%
df.groupby('order_approved_at').count()
# Out:
#                      order_id  customer_id  order_status  \
# order_approved_at
# 2016-09-15 12:16:38         1            1             1
# 2016-10-04 09:43:32         1            1             1
# 2016-10-04 10:18:57         1            1             1
# 2016-10-04 10:19:23         1            1             1
# 2016-10-04 10:25:46         1            1             1
# ...                       ...          ...           ...
# 2018-08-29 14:30:23         1            1             1
# 2018-08-29 14:31:07         1            1             1
# 2018-08-29 15:05:22         1            1             1
# 2018-08-29 15:10:26         1            1             1
# 2018-09-03 17:40:06         1            1             1
#
#                      order_purchase_timestamp  order_delivered_carrier_date  \
# order_approved_at
# 2016-09-15 12:16:38                         1                             1
# 2016-10-04 09:43:32                         1                             1
# ...

# %% [markdown]
# - It can be seen that we have a data within the 'order_approved_at' column that is repeated nine times, as well as other dates that are repeated 7 times within the data set, until we have the unique data. It should also be noted that it has 160 NaN data in this column.

# %%
df['order_delivered_carrier_date'].value_counts()
# Out:
# 2018-05-09 15:48:00    47
# 2018-05-10 18:29:00    32
# 2018-05-07 12:31:00    21
# 2018-05-02 15:15:00    16
# 2018-07-24 16:07:00    16
#                        ..
# 2018-01-03 17:37:21     1
# 2017-10-27 20:07:58     1
# 2017-11-21 18:57:37     1
# 2018-03-21 20:03:37     1
# 2018-03-09 22:11:59     1
# Name: order_delivered_carrier_date, Length: 81018, dtype: int64

# %%
df['order_delivered_carrier_date'].isnull().sum()
# Out:
# 1783

# %%
df.groupby('order_delivered_carrier_date').count()
# Out:
#                               order_id  customer_id  order_status  \
# order_delivered_carrier_date
# 2016-10-08 10:34:01                  1            1             1
# 2016-10-08 13:46:32                  1            1             1
# 2016-10-08 14:46:49                  1            1             1
# 2016-10-09 02:45:17                  1            1             1
# 2016-10-09 03:45:42                  1            1             1
# ...                                ...          ...           ...
# 2018-08-31 15:09:00                  1            1             1
# 2018-08-31 15:25:00                  1            1             1
# 2018-09-03 12:56:00                  1            1             1
# 2018-09-04 15:25:00                  1            1             1
# 2018-09-11 19:48:28                  1            1             1
#
#                               order_purchase_timestamp  order_approved_at  \
# order_delivered_carrier_date
# ...

# %% [markdown]
# - It can be seen that the column 'order_delivered_carrier_date' has dates that are repeated to a greater extent in 47 opportunities, going down by another 32, 21, some with 16 times that are repeated until reaching the unique values. Also complementing we can say that it has 1783 NaN data within this column.

# %%
df['order_delivered_customer_date'].value_counts()
# Out:
# 2018-05-08 23:38:46    3
# 2016-10-27 17:32:07    3
# 2018-02-14 21:09:19    3
# 2017-06-19 18:47:51    3
# 2018-05-08 19:36:48    3
#                       ..
# 2018-07-12 17:48:45    1
# 2018-05-18 18:24:36    1
# 2018-01-17 13:29:13    1
# 2018-06-29 11:21:34    1
# 2018-03-16 13:08:30    1
# Name: order_delivered_customer_date, Length: 95664, dtype: int64

# %%
df['order_delivered_customer_date'].isnull().sum()
# Out:
# 2965

# %%
df.groupby('order_delivered_customer_date').count()
# Out:
#                                order_id  customer_id  order_status  \
# order_delivered_customer_date
# 2016-10-11 13:46:32                   1            1             1
# 2016-10-11 14:46:49                   1            1             1
# 2016-10-13 03:10:34                   1            1             1
# 2016-10-13 07:45:48                   1            1             1
# 2016-10-13 15:44:27                   1            1             1
# ...                                 ...          ...           ...
# 2018-09-25 00:47:25                   1            1             1
# 2018-09-27 02:24:33                   1            1             1
# 2018-10-02 00:18:50                   1            1             1
# 2018-10-11 16:41:14                   1            1             1
# 2018-10-17 13:22:46                   1            1             1
#
#                                order_purchase_timestamp  order_approved_at  \
# order_delivered_customer_date
# ...

# %% [markdown]
# - Within the 'order_delivered_customer_date' column we can see that it has several dates whose repetition frequency is 3, until reaching the unique values. It should also be noted that this column has 2965 data whose values are NaN.

# %%
df['order_estimated_delivery_date'].value_counts()
# Out:
# 2017-12-20 00:00:00    522
# 2018-03-12 00:00:00    516
# 2018-05-29 00:00:00    513
# 2018-03-13 00:00:00    513
# 2018-02-14 00:00:00    507
#                       ...
# 2016-11-14 00:00:00      1
# 2016-11-07 00:00:00      1
# 2016-09-30 00:00:00      1
# 2016-10-28 00:00:00      1
# 2016-10-27 00:00:00      1
# Name: order_estimated_delivery_date, Length: 459, dtype: int64

# %%
df.groupby('order_estimated_delivery_date').count()
# Out:
#                                order_id  customer_id  order_status  \
# order_estimated_delivery_date
# 2016-09-30 00:00:00                   1            1             1
# 2016-10-04 00:00:00                   1            1             1
# 2016-10-20 00:00:00                   1            1             1
# 2016-10-24 00:00:00                   1            1             1
# 2016-10-25 00:00:00                   1            1             1
# ...                                 ...          ...           ...
# 2018-10-17 00:00:00                   2            2             2
# 2018-10-23 00:00:00                   2            2             2
# 2018-10-25 00:00:00                   2            2             2
# 2018-10-30 00:00:00                   1            1             1
# 2018-11-12 00:00:00                   1            1             1
#
#                                order_purchase_timestamp  order_approved_at  \
# order_estimated_delivery_date
# ...

# %% [markdown]
# - Within the column 'order_estimated_delivery_date' we find dates that are repeated several of them from the value that is repeated the most of 522 until going down to the unique values.
