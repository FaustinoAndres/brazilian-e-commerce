# %% [markdown]
# ### Initial exploratory analysis of the olist_geolocation_dataset.csv table set

# %%
# Import libraries here
# Tool that allows us to import, better manage the data set
import pandas as pd
# Tool that helps us in the mathematical handling of data
import numpy as np
# Library that helps us in data visualization
import matplotlib.pyplot as plt
# Data visualization tool
import seaborn as sns
sns.set_theme(style="darkgrid")
sns.set(rc={'figure.figsize':(15,8.27)})

# %%
# Import data here
df = pd.read_csv("../../data/raw/olist_geolocation_dataset.csv")

# %%
# The method is used to display the first rows of the dataframe
df.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
# At this point we visualize the data of the last rows of the dataframe
df.tail()
# Out:
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 1000158                        99950       -28.068639       -52.010705
# 1000159                        99900       -27.877125       -52.224882
# 1000160                        99950       -28.071855       -52.014716
# 1000161                        99980       -28.388932       -51.846871
# 1000162                        99950       -28.070104       -52.018658
#
#         geolocation_city geolocation_state
# 1000158         tapejara                RS
# 1000159   getulio vargas                RS
# 1000160         tapejara                RS
# 1000161  david canabarro                RS
# 1000162         tapejara                RS

# %%
# Check the number of rows and columns of the dataframe
print(df.shape)
# Out:
# (1000163, 5)

# %%
# We extend information of my dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB

# %%
df.dtypes
# Out:
# geolocation_zip_code_prefix      int64
# geolocation_lat                float64
# geolocation_lng                float64
# geolocation_city                object
# geolocation_state               object
# dtype: object

# %% [markdown]
# - We can see that we have within our data set a column with data, we have numeric data of the integer type in the 'geolocation_zip_code_prefix' column, in the columns where it refers to the latitude and longitude they are of the float or decimal type because the representation Numerical to determine a geographical point, decimal data are used. Regarding the 'geolocation_city' and 'geolocation_state' they are data of the type object or categorical due to their nature, which refers to cities and states respectively.

# %%
df.describe()
# Out:
#        geolocation_zip_code_prefix  geolocation_lat  geolocation_lng
# count                 1.000163e+06     1.000163e+06     1.000163e+06
# mean                  3.657417e+04    -2.117615e+01    -4.639054e+01
# std                   3.054934e+04     5.715866e+00     4.269748e+00
# min                   1.001000e+03    -3.660537e+01    -1.014668e+02
# 25%                   1.107500e+04    -2.360355e+01    -4.857317e+01
# 50%                   2.653000e+04    -2.291938e+01    -4.663788e+01
# 75%                   6.350400e+04    -1.997962e+01    -4.376771e+01
# max                   9.999000e+04     4.506593e+01     1.211054e+02

# %% [markdown]
# - Being geographic data, the data they are taking to give us statistical information refers to the postal code as the locations in latitude and longitude.

# %% [markdown]
# To broaden the panorama of information, we will also include the categorical data and take advantage of the function describe(include='all'), in order to have a greater amount of preliminary information on the data set.

# %%
df.describe(include='all')
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# count                  1.000163e+06     1.000163e+06     1.000163e+06
# unique                          NaN              NaN              NaN
# top                             NaN              NaN              NaN
# freq                            NaN              NaN              NaN
# mean                   3.657417e+04    -2.117615e+01    -4.639054e+01
# std                    3.054934e+04     5.715866e+00     4.269748e+00
# min                    1.001000e+03    -3.660537e+01    -1.014668e+02
# 25%                    1.107500e+04    -2.360355e+01    -4.857317e+01
# 50%                    2.653000e+04    -2.291938e+01    -4.663788e+01
# 75%                    6.350400e+04    -1.997962e+01    -4.376771e+01
# max                    9.999000e+04     4.506593e+01     1.211054e+02
#
#        geolocation_city geolocation_state
# count           1000163           1000163
# ...

# %% [markdown]
# - Regarding the 'geolocation_city' column, it can be seen that there are 8011 categories of which the most repeated is sao paulo.
# - Doing the exploration regarding 'geolocation_state', it can be seen that it has 27 categories, which refers to the 26 states plus the Federal District of Brazil.

# %% [markdown]
# We will proceed to evaluate if within our data set we have null data or NaN and thus be able to know where

# %%
df.isnull().sum()
# Out:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64

# %% [markdown]
# With regard to having null data, it tells us that we do not have null data in our data set

# %%
df['geolocation_zip_code_prefix'].value_counts()
# Out:
# 24220    1146
# 24230    1102
# 38400     965
# 35500     907
# 11680     879
#          ...
# 71750       1
# 71742       1
# 26475       1
# 26357       1
# 29826       1
# Name: geolocation_zip_code_prefix, Length: 19015, dtype: int64

# %%
df.groupby('geolocation_zip_code_prefix').count()
# Out:
#                              geolocation_lat  geolocation_lng  \
# geolocation_zip_code_prefix
# 1001                                      26               26
# 1002                                      13               13
# 1003                                      17               17
# 1004                                      22               22
# 1005                                      25               25
# ...                                      ...              ...
# 99960                                      5                5
# 99965                                      6                6
# 99970                                     21               21
# 99980                                     26               26
# 99990                                      2                2
#
#                              geolocation_city  geolocation_state
# geolocation_zip_code_prefix
# 1001                                       26                 26
# ...

# %% [markdown]
# - Taking into account the zip code prefix represented in the 'geolocation_zip_code_prefix' column, there is a number of times ranging from 1146 times as the highest frequency that is repeated.

# %%
df['geolocation_lat'].value_counts()
# Out:
# -27.102099    314
# -23.495901    190
# -23.506049    141
# -23.490618    127
# -23.005514    102
#              ...
# -23.102130      1
# -22.895678      1
# -22.599157      1
# -22.878048      1
# -28.388932      1
# Name: geolocation_lat, Length: 717360, dtype: int64

# %%
df.groupby('geolocation_lat').count()
# Out:
#                  geolocation_zip_code_prefix  geolocation_lng  \
# geolocation_lat
# -36.605374                                 1                1
# -36.603837                                 2                2
# -34.622400                                 1                1
# -34.586422                                 1                1
# -33.692616                                 1                1
# ...                                      ...              ...
#  42.184003                                 2                2
#  42.428884                                 1                1
#  42.439286                                 1                1
#  43.684961                                 1                1
#  45.065933                                 1                1
#
#                  geolocation_city  geolocation_state
# geolocation_lat
# -36.605374                      1                  1
# -36.603837                      2                  2
# ...

# %% [markdown]
# - Within our data set, the tuples that most coincide do so 314 times.

# %%
df['geolocation_lng'].value_counts()
# Out:
# -48.629613    314
# -46.874687    190
# -46.717377    141
# -46.869004    127
# -43.375964    102
#              ...
# -48.451196      1
# -48.429817      1
# -48.616300      1
# -48.425129      1
# -51.846871      1
# Name: geolocation_lng, Length: 717613, dtype: int64

# %%
df.groupby('geolocation_lng').count()
# Out:
#                  geolocation_zip_code_prefix  geolocation_lat  \
# geolocation_lng
# -101.466766                                1                1
# -98.484121                                 1                1
# -98.078544                                 1                1
# -98.078533                                 1                1
# -72.930746                                 1                1
# ...                                      ...              ...
# -6.328200                                  1                1
# -4.947823                                  1                1
#  9.341528                                  1                1
#  13.820214                                 1                1
#  121.105394                                1                1
#
#                  geolocation_city  geolocation_state
# geolocation_lng
# -101.466766                     1                  1
# -98.484121                      1                  1
# ...

# %% [markdown]
# - We can confirm that the numbers in longitude also coincide a priori the same number of times as in latitude, which gives us an indication that geographically, with respect to these values, no type of inconsistency is generated in the data set.

# %%
df['geolocation_city'].value_counts()
# Out:
# sao paulo               135800
# rio de janeiro           62151
# belo horizonte           27805
# são paulo                24918
# curitiba                 16593
#                          ...
# jacuípe                      1
# mar vermelho                 1
# quebrangulo                  1
# poço das trincheiras         1
# poxim                        1
# Name: geolocation_city, Length: 8011, dtype: int64

# %%
df.groupby('geolocation_city').count()
# Out:
#                     geolocation_zip_code_prefix  geolocation_lat  \
# geolocation_city
# * cidade                                      1                1
# ...arraial do cabo                            1                1
# 4o. centenario                                1                1
# 4º centenario                                 2                2
# abadia de goias                               8                8
# ...                                         ...              ...
# áurea                                         2                2
# ângulo                                        4                4
# érico cardoso                                 1                1
# óbidos                                       11               11
# óleo                                          4                4
#
#                     geolocation_lng  geolocation_state
# geolocation_city
# * cidade                          1                  1
# ...

# %% [markdown]
# - You can see the cities with the highest number of repetitions in our data set, in which the first 5 stand out are Sao Paulo, Rio de Janeiro, Belo Horizonte, Sao Paulo and Curitiba.
# - Now in this previous analysis it is giving us details that there are two ways in which one of the categories is being called, which is São Paulo and São Paulo, which is the time to generate research if within Brazil there are two nomenclatures to represent different cities. or they represent the place itself, which will lead us to be able to generate a normalization with respect to that particular category.

# %%
df['geolocation_state'].value_counts()
# Out:
# SP    404268
# MG    126336
# RJ    121169
# RS     61851
# PR     57859
# SC     38328
# BA     36045
# GO     20139
# ES     16748
# PE     16432
# DF     12986
# MT     12031
# CE     11674
# PA     10853
# MS     10431
# MA      7853
# PB      5538
# RN      5041
# PI      4549
# AL      4183
# TO      3576
# SE      3563
# RO      3478
# AM      2432
# AC      1301
# AP       853
# RR       646
# Name: geolocation_state, dtype: int64

# %%
df.groupby('geolocation_state').count()
# Out:
#                    geolocation_zip_code_prefix  geolocation_lat  \
# geolocation_state
# AC                                        1301             1301
# AL                                        4183             4183
# AM                                        2432             2432
# AP                                         853              853
# BA                                       36045            36045
# CE                                       11674            11674
# DF                                       12986            12986
# ES                                       16748            16748
# GO                                       20139            20139
# MA                                        7853             7853
# MG                                      126336           126336
# MS                                       10431            10431
# MT                                       12031            12031
# ...

# %%
sns.countplot(y='geolocation_state', data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='geolocation_state'>

# %% [markdown]
# - Regarding the 'geolocation state' column, its 27 categories are observed where there is a greater number of tuples with reference to the 'SP' state.
