# %%
import os
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset_path = "../../data/raw/"

# %% [markdown]
# ### ***Analyzing the files***

# %%
files = os.listdir(dataset_path)
print(f'The dataset contains {len(files)} files:')
for file in files:
    print(f'    * {file}')
# Out:
# The dataset contains 9 files:
#     * olist_customers_dataset.csv
#     * olist_geolocation_dataset.csv
#     * olist_orders_dataset.csv
#     * olist_order_items_dataset.csv
#     * olist_order_payments_dataset.csv
#     * olist_order_reviews_dataset.csv
#     * olist_products_dataset.csv
#     * olist_sellers_dataset.csv
#     * product_category_name_translation.csv

# %% [markdown]
# ### ***Getting info from tables***
# #### column_name, dtype, rows_count, non_null_rows_count, null_row_count, unique_value_count

# %%
def tables_info(dataset_path, csv_file_name):
    # csv_file_name = 'olist_customers_dataset.csv'
    csv_file_path = os.path.join(dataset_path, csv_file_name)
    df = pd.read_csv(csv_file_path)
    # print(df.head(5))
    # print(df.columns.shape[0])    
    info_df = pd.DataFrame(data=[], index=df.columns)            
    info_df.loc[:, 'table_name'] = csv_file_name.split('.')[0]
    info_df.loc[:, 'entities'] = info_df['table_name'].str.split('_dataset').str[0].str.split('olist_').str[-1]
    info_df.loc[:, 'column_name'] = df.columns
    for column in df.columns:           
        info_df.loc[column, 'dtype'] = df[column].dtypes   
        info_df.loc[column,'rows_count'] = df[column].shape[0]
        info_df.loc[column,'non_null_rows_count'] =df[column].notnull().sum()
        info_df.loc[column,'null_row_count'] =df[column].isna().sum()
        info_df.loc[column,'unique_value_count'] = df[column].unique().shape[0]

    info_df.reset_index(drop=True, inplace=True)        
    return info_df

# %% [markdown]
# #### ***For only one table***

# %%
info_df = tables_info(dataset_path, csv_file_name='olist_orders_dataset.csv')
info_df
# Out:
#              table_name entities                    column_name   dtype  \
# 0  olist_orders_dataset   orders                       order_id  object
# 1  olist_orders_dataset   orders                    customer_id  object
# 2  olist_orders_dataset   orders                   order_status  object
# 3  olist_orders_dataset   orders       order_purchase_timestamp  object
# 4  olist_orders_dataset   orders              order_approved_at  object
# 5  olist_orders_dataset   orders   order_delivered_carrier_date  object
# 6  olist_orders_dataset   orders  order_delivered_customer_date  object
# 7  olist_orders_dataset   orders  order_estimated_delivery_date  object
#
#    rows_count  non_null_rows_count  null_row_count  unique_value_count
# 0     99441.0              99441.0             0.0             99441.0
# 1     99441.0              99441.0             0.0             99441.0
# 2     99441.0              99441.0             0.0                 8.0
# 3     99441.0              99441.0             0.0             98875.0
# 4     99441.0              99281.0           160.0             90734.0
# 5     99441.0              97658.0          1783.0             81019.0
# 6     99441.0              96476.0          2965.0             95665.0
# 7     99441.0              99441.0             0.0               459.0

# %%
info_df = pd.DataFrame([])
# print(info_df)
for file in files:
    print(f"{file}")
    info_df1 = tables_info(dataset_path, file)    
    if info_df.empty:
        # print('DataFrame is empty!')
        info_df = info_df1.copy()
    else:
        info_df = pd.concat([info_df, info_df1], axis=0)

info_df.reset_index(drop=True, inplace=True)
# Out:
# olist_customers_dataset.csv
# olist_geolocation_dataset.csv
# olist_orders_dataset.csv
# olist_order_items_dataset.csv
# olist_order_payments_dataset.csv
# olist_order_reviews_dataset.csv
# olist_products_dataset.csv
# olist_sellers_dataset.csv
# product_category_name_translation.csv

# %% [markdown]
# #### ***For only one table***

# %%
info_df
# Out:
#                            table_name                           entities  \
# 0             olist_customers_dataset                          customers
# 1             olist_customers_dataset                          customers
# 2             olist_customers_dataset                          customers
# 3             olist_customers_dataset                          customers
# 4             olist_customers_dataset                          customers
# 5           olist_geolocation_dataset                        geolocation
# 6           olist_geolocation_dataset                        geolocation
# 7           olist_geolocation_dataset                        geolocation
# 8           olist_geolocation_dataset                        geolocation
# 9           olist_geolocation_dataset                        geolocation
# 10               olist_orders_dataset                             orders
# 11               olist_orders_dataset                             orders
# 12               olist_orders_dataset                             orders
# 13               olist_orders_dataset                             orders
# 14               olist_orders_dataset                             orders
# 15               olist_orders_dataset                             orders
# 16               olist_orders_dataset                             orders
# 17               olist_orders_dataset                             orders
# 18          olist_order_items_dataset                        order_items
# 19          olist_order_items_dataset                        order_items
# 20          olist_order_items_dataset                        order_items
# 21          olist_order_items_dataset                        order_items
# 22          olist_order_items_dataset                        order_items
# 23          olist_order_items_dataset                        order_items
# 24          olist_order_items_dataset                        order_items
# 25       olist_order_payments_dataset                     order_payments
# 26       olist_order_payments_dataset                     order_payments
# 27       olist_order_payments_dataset                     order_payments
# 28       olist_order_payments_dataset                     order_payments
# 29       olist_order_payments_dataset                     order_payments
# 30        olist_order_reviews_dataset                      order_reviews
# 31        olist_order_reviews_dataset                      order_reviews
# 32        olist_order_reviews_dataset                      order_reviews
# 33        olist_order_reviews_dataset                      order_reviews
# 34        olist_order_reviews_dataset                      order_reviews
# 35        olist_order_reviews_dataset                      order_reviews
# 36        olist_order_reviews_dataset                      order_reviews
# 37             olist_products_dataset                           products
# 38             olist_products_dataset                           products
# 39             olist_products_dataset                           products
# 40             olist_products_dataset                           products
# 41             olist_products_dataset                           products
# 42             olist_products_dataset                           products
# 43             olist_products_dataset                           products
# 44             olist_products_dataset                           products
# 45             olist_products_dataset                           products
# 46              olist_sellers_dataset                            sellers
# 47              olist_sellers_dataset                            sellers
# 48              olist_sellers_dataset                            sellers
# 49              olist_sellers_dataset                            sellers
# 50  product_category_name_translation  product_category_name_translation
# 51  product_category_name_translation  product_category_name_translation
#
#                       column_name    dtype  rows_count  non_null_rows_count  \
# 0                     customer_id   object     99441.0              99441.0
# 1              customer_unique_id   object     99441.0              99441.0
# 2        customer_zip_code_prefix    int64     99441.0              99441.0
# 3                   customer_city   object     99441.0              99441.0
# 4                  customer_state   object     99441.0              99441.0
# 5     geolocation_zip_code_prefix    int64   1000163.0            1000163.0
# 6                 geolocation_lat  float64   1000163.0            1000163.0
# 7                 geolocation_lng  float64   1000163.0            1000163.0
# 8                geolocation_city   object   1000163.0            1000163.0
# 9               geolocation_state   object   1000163.0            1000163.0
# 10                       order_id   object     99441.0              99441.0
# 11                    customer_id   object     99441.0              99441.0
# 12                   order_status   object     99441.0              99441.0
# 13       order_purchase_timestamp   object     99441.0              99441.0
# 14              order_approved_at   object     99441.0              99281.0
# 15   order_delivered_carrier_date   object     99441.0              97658.0
# 16  order_delivered_customer_date   object     99441.0              96476.0
# 17  order_estimated_delivery_date   object     99441.0              99441.0
# 18                       order_id   object    112650.0             112650.0
# 19                  order_item_id    int64    112650.0             112650.0
# 20                     product_id   object    112650.0             112650.0
# 21                      seller_id   object    112650.0             112650.0
# 22            shipping_limit_date   object    112650.0             112650.0
# 23                          price  float64    112650.0             112650.0
# 24                  freight_value  float64    112650.0             112650.0
# 25                       order_id   object    103886.0             103886.0
# 26             payment_sequential    int64    103886.0             103886.0
# 27                   payment_type   object    103886.0             103886.0
# 28           payment_installments    int64    103886.0             103886.0
# 29                  payment_value  float64    103886.0             103886.0
# 30                      review_id   object     99224.0              99224.0
# 31                       order_id   object     99224.0              99224.0
# 32                   review_score    int64     99224.0              99224.0
# 33           review_comment_title   object     99224.0              11568.0
# 34         review_comment_message   object     99224.0              40977.0
# 35           review_creation_date   object     99224.0              99224.0
# 36        review_answer_timestamp   object     99224.0              99224.0
# 37                     product_id   object     32951.0              32951.0
# 38          product_category_name   object     32951.0              32341.0
# 39            product_name_lenght  float64     32951.0              32341.0
# 40     product_description_lenght  float64     32951.0              32341.0
# 41             product_photos_qty  float64     32951.0              32341.0
# 42               product_weight_g  float64     32951.0              32949.0
# 43              product_length_cm  float64     32951.0              32949.0
# 44              product_height_cm  float64     32951.0              32949.0
# 45               product_width_cm  float64     32951.0              32949.0
# 46                      seller_id   object      3095.0               3095.0
# 47         seller_zip_code_prefix    int64      3095.0               3095.0
# 48                    seller_city   object      3095.0               3095.0
# 49                   seller_state   object      3095.0               3095.0
# 50          product_category_name   object        71.0                 71.0
# 51  product_category_name_english   object        71.0                 71.0
#
#     null_row_count  unique_value_count
# 0              0.0             99441.0
# 1              0.0             96096.0
# 2              0.0             14994.0
# 3              0.0              4119.0
# 4              0.0                27.0
# 5              0.0             19015.0
# 6              0.0            717360.0
# 7              0.0            717613.0
# 8              0.0              8011.0
# 9              0.0                27.0
# 10             0.0             99441.0
# 11             0.0             99441.0
# 12             0.0                 8.0
# 13             0.0             98875.0
# 14           160.0             90734.0
# 15          1783.0             81019.0
# 16          2965.0             95665.0
# 17             0.0               459.0
# 18             0.0             98666.0
# 19             0.0                21.0
# 20             0.0             32951.0
# 21             0.0              3095.0
# 22             0.0             93318.0
# 23             0.0              5968.0
# 24             0.0              6999.0
# 25             0.0             99440.0
# 26             0.0                29.0
# 27             0.0                 5.0
# 28             0.0                24.0
# 29             0.0             29077.0
# 30             0.0             98410.0
# 31             0.0             98673.0
# 32             0.0                 5.0
# 33         87656.0              4528.0
# 34         58247.0             36160.0
# 35             0.0               636.0
# 36             0.0             98248.0
# 37             0.0             32951.0
# 38           610.0                74.0
# 39           610.0                67.0
# 40           610.0              2961.0
# 41           610.0                20.0
# 42             2.0              2205.0
# 43             2.0               100.0
# 44             2.0               103.0
# 45             2.0                96.0
# 46             0.0              3095.0
# 47             0.0              2246.0
# 48             0.0               611.0
# 49             0.0                23.0
# 50             0.0                71.0
# 51             0.0                71.0

# %% [markdown]
# #### ***Total number of columns***

# %%
info_df.groupby('table_name')['column_name'].count().sum()
# Out:
# 52

# %% [markdown]
# #### ***Total number of dtypes***

# %%
info_df['dtype'].value_counts()
# Out:
# object     33
# float64    12
# int64       7
# Name: dtype, dtype: int64

# %% [markdown]
# #### ***Most repeated columns in tables***

# %%
info_df['column_name'].value_counts()[0:6]
# Out:
# order_id                 4
# customer_id              2
# product_category_name    2
# seller_id                2
# product_id               2
# payment_value            1
# Name: column_name, dtype: int64

# %% [markdown]
# #### ***Looking for related columns and tables***

# %%
info_df_new = info_df[['entities', 'column_name']].copy()
info_df_new['present_at_table'] = np.nan
info_df_new['present_#_tables'] = np.nan
for i, row in info_df_new.iterrows():
    item = row['column_name']
    # print(item)
    value = info_df_new[info_df_new['column_name']== item]['entities'].to_list()
    info_df_new['present_at_table'][i] = value    
    info_df_new['present_#_tables'][i] = len(value)
info_df_new_sort = info_df_new.sort_values(by='present_#_tables', ascending=False)
info_df_new_clean = info_df_new_sort.drop_duplicates(subset=['column_name'])[['column_name', 'present_at_table', 'present_#_tables']]
info_df_new_clean = info_df_new_clean[info_df_new_clean['present_#_tables'] > 1].reset_index(drop=True)
info_df_new_clean
# Out:
# /tmp/ipykernel_703/171940302.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   info_df_new['present_at_table'][i] = value
# /home/roruizf/anaconda3/envs/data_env/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /tmp/ipykernel_703/171940302.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   info_df_new['present_#_tables'][i] = len(value)
#              column_name                                   present_at_table  \
# 0               order_id  [orders, order_items, order_payments, order_re...
# 1            customer_id                                [customers, orders]
# 2             product_id                            [order_items, products]
# 3              seller_id                             [order_items, sellers]
# 4  product_category_name      [products, product_category_name_translation]
#
#    present_#_tables
# 0               4.0
# 1               2.0
# 2               2.0
# 3               2.0
# 4               2.0

# %%
info_df_new_clean['present_at_table'][0]
# Out:
# ['orders', 'order_items', 'order_payments', 'order_reviews']

# %%
info_df[info_df['column_name'] == "order_id"]
# Out:
#                       table_name        entities column_name   dtype  \
# 10          olist_orders_dataset          orders    order_id  object
# 18     olist_order_items_dataset     order_items    order_id  object
# 25  olist_order_payments_dataset  order_payments    order_id  object
# 31   olist_order_reviews_dataset   order_reviews    order_id  object
#
#     rows_count  non_null_rows_count  null_row_count  unique_value_count
# 10     99441.0              99441.0             0.0             99441.0
# 18    112650.0             112650.0             0.0             98666.0
# 25    103886.0             103886.0             0.0             99440.0
# 31     99224.0              99224.0             0.0             98673.0

# %% [markdown]
# ### ***Database table relationships (from kaggle)***
# <img src="https://i.imgur.com/HRhd2Y0.png" alt="Database table relationships" style="height: 600px; width:1000px;"/>

# %% [markdown]
# ### ***Getting columns data types and constraints***

# %%
def data_subtype(df, column):
    # column = df.columns[4]
    # print(column)
    df = df[df[column].notnull()].reset_index(drop=True) #Remove possible not null values
    # dtype
    # print(df[column].dtype)
    if df[column].dtype == 'object':    
        #Date/time or str?
        try: #Date/time: Up to now only datetime
            x = pd.to_datetime(df[column], infer_datetime_format=True)                   
            data_subtype = x.dtype

        except: #if it fails -> str
            if df[column].str.len().unique().shape[0] == 1: #All the elements have the same length if == 1
                data_subtype = f"CHAR({df[column].str.len().unique()[0]})"
            elif df[column].map(lambda x: len(x)).max() > 255: #Variable length higher than 255
                data_subtype = 'TEXT()' 
            else:
                # data_type = f"VARCHAR({df[column].map(lambda x: len(x)).max()})"   
                data_subtype = f"VARCHAR(255)"       
    elif df[column].dtype == 'float64':
        # print(df[column].dtype)
        data_subtype = df[column].dtype
    else: #int64
        # print(df[column].dtype)
        data_subtype = df[column].dtype
    # print(data_subtype)
    example = df[column][random.randint(0,df[column].shape[0])]
    return [data_subtype, example]

# %%
def tables_info2(dataset_path, csv_file_name):
    # csv_file_name = 'olist_customers_dataset.csv'
    csv_file_path = os.path.join(dataset_path, csv_file_name)
    df = pd.read_csv(csv_file_path)
    # print(df.head(5))
    # print(df.columns.shape[0])    
    info_df = pd.DataFrame(data=[], index=df.columns)            
    info_df.loc[:, 'table_name'] = csv_file_name.split('.')[0]
    info_df.loc[:, 'entities'] = info_df['table_name'].str.split('_dataset').str[0].str.split('olist_').str[-1]
    info_df.loc[:, 'column_name'] = df.columns
    for column in df.columns:           
        info_df.loc[column, 'dtype'] = df[column].dtypes
        data_subtype_example = data_subtype(df, column)
        info_df.loc[column, 'subtype'] = data_subtype_example[0]
        info_df.loc[column, 'example'] = data_subtype_example[1]
        info_df.loc[column,'unique_value_count'] = df[column].unique().shape[0]
        info_df.loc[column,'is_not_null'] =~df[column].isnull().values.any()
        info_df.loc[column, 'is_unique'] = df[column].is_unique        
        info_df.loc[column, 'is_primary_key'] = (column.find('_id') != -1) & info_df.loc[column,'is_not_null'] & info_df.loc[column, 'is_unique']
        info_df.loc[column, 'is_foreign_key'] = (column.find('_id') != -1) & ~info_df.loc[column, 'is_primary_key']
        info_df.loc[column,'is_id'] = (column.find('_id') != -1)       

    info_df.reset_index(drop=True, inplace=True)        
    return info_df

# %% [markdown]
# #### ***For only one table***

# %%
csv_file_name='olist_orders_dataset.csv'
# csv_file_name = 'olist_order_items_dataset.csv'
df = tables_info2(dataset_path, csv_file_name)
df
# Out:
#              table_name entities                    column_name   dtype  \
# 0  olist_orders_dataset   orders                       order_id  object
# 1  olist_orders_dataset   orders                    customer_id  object
# 2  olist_orders_dataset   orders                   order_status  object
# 3  olist_orders_dataset   orders       order_purchase_timestamp  object
# 4  olist_orders_dataset   orders              order_approved_at  object
# 5  olist_orders_dataset   orders   order_delivered_carrier_date  object
# 6  olist_orders_dataset   orders  order_delivered_customer_date  object
# 7  olist_orders_dataset   orders  order_estimated_delivery_date  object
#
#           subtype                           example  unique_value_count  \
# 0        CHAR(32)  c7b4a7a4d974418197e38cc0f6c2ea85             99441.0
# 1        CHAR(32)  431bdad95e6781a18b295b98d87335fc             99441.0
# 2    VARCHAR(255)                         delivered                 8.0
# 3  datetime64[ns]               2018-02-21 12:23:15             98875.0
# 4  datetime64[ns]               2017-07-17 18:23:33             90734.0
# 5  datetime64[ns]               2018-01-25 21:42:52             81019.0
# 6  datetime64[ns]               2017-05-04 17:34:52             95665.0
# 7  datetime64[ns]               2018-07-24 00:00:00               459.0
#
#   is_not_null is_unique is_primary_key is_foreign_key  is_id
# 0        True      True           True          False   True
# 1        True      True           True          False   True
# 2        True     False          False          False  False
# 3        True     False          False          False  False
# 4       False     False          False          False  False
# 5       False     False          False          False  False
# 6       False     False          False          False  False
# 7        True     False          False          False  False

# %% [markdown]
# #### ***For all the tables***

# %%
info_df = pd.DataFrame([])
# print(info_df)
for file in files:
    print(f"{file}")
    info_df1 = tables_info2(dataset_path, file)    
    if info_df.empty:
        # print('DataFrame is empty!')
        info_df = info_df1.copy()
    else:
        info_df = pd.concat([info_df, info_df1], axis=0)

info_df.reset_index(drop=True, inplace=True)
# Out:
# olist_customers_dataset.csv
# olist_geolocation_dataset.csv
# olist_orders_dataset.csv
# olist_order_items_dataset.csv
# olist_order_payments_dataset.csv
# olist_order_reviews_dataset.csv
# olist_products_dataset.csv
# olist_sellers_dataset.csv
# product_category_name_translation.csv

# %%
info_df
# Out:
#                            table_name                           entities  \
# 0             olist_customers_dataset                          customers
# 1             olist_customers_dataset                          customers
# 2             olist_customers_dataset                          customers
# 3             olist_customers_dataset                          customers
# 4             olist_customers_dataset                          customers
# 5           olist_geolocation_dataset                        geolocation
# 6           olist_geolocation_dataset                        geolocation
# 7           olist_geolocation_dataset                        geolocation
# 8           olist_geolocation_dataset                        geolocation
# 9           olist_geolocation_dataset                        geolocation
# 10               olist_orders_dataset                             orders
# 11               olist_orders_dataset                             orders
# 12               olist_orders_dataset                             orders
# 13               olist_orders_dataset                             orders
# 14               olist_orders_dataset                             orders
# 15               olist_orders_dataset                             orders
# 16               olist_orders_dataset                             orders
# 17               olist_orders_dataset                             orders
# 18          olist_order_items_dataset                        order_items
# 19          olist_order_items_dataset                        order_items
# 20          olist_order_items_dataset                        order_items
# 21          olist_order_items_dataset                        order_items
# 22          olist_order_items_dataset                        order_items
# 23          olist_order_items_dataset                        order_items
# 24          olist_order_items_dataset                        order_items
# 25       olist_order_payments_dataset                     order_payments
# 26       olist_order_payments_dataset                     order_payments
# 27       olist_order_payments_dataset                     order_payments
# 28       olist_order_payments_dataset                     order_payments
# 29       olist_order_payments_dataset                     order_payments
# 30        olist_order_reviews_dataset                      order_reviews
# 31        olist_order_reviews_dataset                      order_reviews
# 32        olist_order_reviews_dataset                      order_reviews
# 33        olist_order_reviews_dataset                      order_reviews
# 34        olist_order_reviews_dataset                      order_reviews
# 35        olist_order_reviews_dataset                      order_reviews
# 36        olist_order_reviews_dataset                      order_reviews
# 37             olist_products_dataset                           products
# 38             olist_products_dataset                           products
# 39             olist_products_dataset                           products
# 40             olist_products_dataset                           products
# 41             olist_products_dataset                           products
# 42             olist_products_dataset                           products
# 43             olist_products_dataset                           products
# 44             olist_products_dataset                           products
# 45             olist_products_dataset                           products
# 46              olist_sellers_dataset                            sellers
# 47              olist_sellers_dataset                            sellers
# 48              olist_sellers_dataset                            sellers
# 49              olist_sellers_dataset                            sellers
# 50  product_category_name_translation  product_category_name_translation
# 51  product_category_name_translation  product_category_name_translation
#
#                       column_name    dtype         subtype  \
# 0                     customer_id   object        CHAR(32)
# 1              customer_unique_id   object        CHAR(32)
# 2        customer_zip_code_prefix    int64           int64
# 3                   customer_city   object    VARCHAR(255)
# 4                  customer_state   object         CHAR(2)
# 5     geolocation_zip_code_prefix    int64           int64
# 6                 geolocation_lat  float64         float64
# 7                 geolocation_lng  float64         float64
# 8                geolocation_city   object    VARCHAR(255)
# 9               geolocation_state   object         CHAR(2)
# 10                       order_id   object        CHAR(32)
# 11                    customer_id   object        CHAR(32)
# 12                   order_status   object    VARCHAR(255)
# 13       order_purchase_timestamp   object  datetime64[ns]
# 14              order_approved_at   object  datetime64[ns]
# 15   order_delivered_carrier_date   object  datetime64[ns]
# 16  order_delivered_customer_date   object  datetime64[ns]
# 17  order_estimated_delivery_date   object  datetime64[ns]
# 18                       order_id   object        CHAR(32)
# 19                  order_item_id    int64           int64
# 20                     product_id   object        CHAR(32)
# 21                      seller_id   object        CHAR(32)
# 22            shipping_limit_date   object  datetime64[ns]
# 23                          price  float64         float64
# 24                  freight_value  float64         float64
# 25                       order_id   object        CHAR(32)
# 26             payment_sequential    int64           int64
# 27                   payment_type   object    VARCHAR(255)
# 28           payment_installments    int64           int64
# 29                  payment_value  float64         float64
# 30                      review_id   object        CHAR(32)
# 31                       order_id   object        CHAR(32)
# 32                   review_score    int64           int64
# 33           review_comment_title   object    VARCHAR(255)
# 34         review_comment_message   object    VARCHAR(255)
# 35           review_creation_date   object  datetime64[ns]
# 36        review_answer_timestamp   object  datetime64[ns]
# 37                     product_id   object        CHAR(32)
# 38          product_category_name   object    VARCHAR(255)
# 39            product_name_lenght  float64         float64
# 40     product_description_lenght  float64         float64
# 41             product_photos_qty  float64         float64
# 42               product_weight_g  float64         float64
# 43              product_length_cm  float64         float64
# 44              product_height_cm  float64         float64
# 45               product_width_cm  float64         float64
# 46                      seller_id   object        CHAR(32)
# 47         seller_zip_code_prefix    int64           int64
# 48                    seller_city   object    VARCHAR(255)
# 49                   seller_state   object         CHAR(2)
# 50          product_category_name   object    VARCHAR(255)
# 51  product_category_name_english   object    VARCHAR(255)
#
#                                               example  unique_value_count  \
# 0                    59c56e683b39c2ca0c21348d5e5eac99             99441.0
# 1                    e6eb191ddc04af07531ff36d2caca1ff             96096.0
# 2                                               13566             14994.0
# 3                                           fortaleza              4119.0
# 4                                                  SP                27.0
# 5                                             11900.0             19015.0
# 6                                           -22.90042            717360.0
# 7                                          -46.576368            717613.0
# 8                                            ivinhema              8011.0
# 9                                                  RJ                27.0
# 10                   38eb04fead5a8c966e7e01b87830b50e             99441.0
# 11                   04ba9496f04b0eaa070def5b5ab662ac             99441.0
# 12                                          delivered                 8.0
# 13                                2017-08-21 15:43:18             98875.0
# 14                                2018-06-24 22:38:23             90734.0
# 15                                2017-11-06 16:22:15             81019.0
# 16                                2017-08-27 16:21:41             95665.0
# 17                                2017-07-28 00:00:00               459.0
# 18                   6dd0712b5d9d31ab2b006f7b510e8720             98666.0
# 19                                                  1                21.0
# 20                   19c91ef95d509ea33eda93495c4d3481             32951.0
# 21                   744dac408745240a2c2528fb1b6028f3              3095.0
# 22                                2018-03-07 14:56:54             93318.0
# 23                                               65.0              5968.0
# 24                                              18.98              6999.0
# 25                   51e827dc634ca855acba1d305c4649af             99440.0
# 26                                                  1                29.0
# 27                                        credit_card                 5.0
# 28                                                  7                24.0
# 29                                               4.17             29077.0
# 30                   2d5f45068d4eb8c87f3d9bfa87311a5c             98410.0
# 31                   452f45581d396d07e3a7e9f4b4daf866             98673.0
# 32                                                  5                 5.0
# 33                                           Perfeito              4528.0
# 34  entrega deficiente, a NT foi emitida em 31 de ...             36160.0
# 35                                2018-01-09 00:00:00               636.0
# 36                                2017-05-09 16:35:14             98248.0
# 37                   6fa8b8abbb489a0abba6ad7b79c7ecd9             32951.0
# 38                                        moveis_sala                74.0
# 39                                               33.0                67.0
# 40                                              624.0              2961.0
# 41                                                1.0                20.0
# 42                                              200.0              2205.0
# 43                                               35.0               100.0
# 44                                               41.0               103.0
# 45                                               16.0                96.0
# 46                   891071be6ba827b591264c90c2ae8a63              3095.0
# 47                                              88215              2246.0
# 48                                           ibitinga               611.0
# 49                                                 SP                23.0
# 50                        fashion_bolsas_e_acessorios                71.0
# 51                                               food                71.0
#
#    is_not_null is_unique is_primary_key is_foreign_key  is_id
# 0         True      True           True          False   True
# 1         True     False          False           True   True
# 2         True     False          False          False  False
# 3         True     False          False          False  False
# 4         True     False          False          False  False
# 5         True     False          False          False  False
# 6         True     False          False          False  False
# 7         True     False          False          False  False
# 8         True     False          False          False  False
# 9         True     False          False          False  False
# 10        True      True           True          False   True
# 11        True      True           True          False   True
# 12        True     False          False          False  False
# 13        True     False          False          False  False
# 14       False     False          False          False  False
# 15       False     False          False          False  False
# 16       False     False          False          False  False
# 17        True     False          False          False  False
# 18        True     False          False           True   True
# 19        True     False          False           True   True
# 20        True     False          False           True   True
# 21        True     False          False           True   True
# 22        True     False          False          False  False
# 23        True     False          False          False  False
# 24        True     False          False          False  False
# 25        True     False          False           True   True
# 26        True     False          False          False  False
# 27        True     False          False          False  False
# 28        True     False          False          False  False
# 29        True     False          False          False  False
# 30        True     False          False           True   True
# 31        True     False          False           True   True
# 32        True     False          False          False  False
# 33       False     False          False          False  False
# 34       False     False          False          False  False
# 35        True     False          False          False  False
# 36        True     False          False          False  False
# 37        True      True           True          False   True
# 38       False     False          False          False  False
# 39       False     False          False          False  False
# 40       False     False          False          False  False
# 41       False     False          False          False  False
# 42       False     False          False          False  False
# 43       False     False          False          False  False
# 44       False     False          False          False  False
# 45       False     False          False          False  False
# 46        True      True           True          False   True
# 47        True     False          False          False  False
# 48        True     False          False          False  False
# 49        True     False          False          False  False
# 50        True      True          False          False  False
# 51        True      True          False          False  False

# %% [markdown]
# ##### ***Checking why not every table has its own primary_key***

# %%
info_df[info_df["is_primary_key"]==True]
# Out:
#                  table_name   entities  column_name   dtype   subtype  \
# 0   olist_customers_dataset  customers  customer_id  object  CHAR(32)
# 10     olist_orders_dataset     orders     order_id  object  CHAR(32)
# 11     olist_orders_dataset     orders  customer_id  object  CHAR(32)
# 37   olist_products_dataset   products   product_id  object  CHAR(32)
# 46    olist_sellers_dataset    sellers    seller_id  object  CHAR(32)
#
#                              example  unique_value_count is_not_null  \
# 0   59c56e683b39c2ca0c21348d5e5eac99             99441.0        True
# 10  38eb04fead5a8c966e7e01b87830b50e             99441.0        True
# 11  04ba9496f04b0eaa070def5b5ab662ac             99441.0        True
# 37  6fa8b8abbb489a0abba6ad7b79c7ecd9             32951.0        True
# 46  891071be6ba827b591264c90c2ae8a63              3095.0        True
#
#    is_unique is_primary_key is_foreign_key is_id
# 0       True           True          False  True
# 10      True           True          False  True
# 11      True           True          False  True
# 37      True           True          False  True
# 46      True           True          False  True

# %%
info_df[info_df["is_id"]==True]
# Out:
#                       table_name        entities         column_name   dtype  \
# 0        olist_customers_dataset       customers         customer_id  object
# 1        olist_customers_dataset       customers  customer_unique_id  object
# 10          olist_orders_dataset          orders            order_id  object
# 11          olist_orders_dataset          orders         customer_id  object
# 18     olist_order_items_dataset     order_items            order_id  object
# 19     olist_order_items_dataset     order_items       order_item_id   int64
# 20     olist_order_items_dataset     order_items          product_id  object
# 21     olist_order_items_dataset     order_items           seller_id  object
# 25  olist_order_payments_dataset  order_payments            order_id  object
# 30   olist_order_reviews_dataset   order_reviews           review_id  object
# 31   olist_order_reviews_dataset   order_reviews            order_id  object
# 37        olist_products_dataset        products          product_id  object
# 46         olist_sellers_dataset         sellers           seller_id  object
#
#      subtype                           example  unique_value_count  \
# 0   CHAR(32)  59c56e683b39c2ca0c21348d5e5eac99             99441.0
# 1   CHAR(32)  e6eb191ddc04af07531ff36d2caca1ff             96096.0
# 10  CHAR(32)  38eb04fead5a8c966e7e01b87830b50e             99441.0
# 11  CHAR(32)  04ba9496f04b0eaa070def5b5ab662ac             99441.0
# 18  CHAR(32)  6dd0712b5d9d31ab2b006f7b510e8720             98666.0
# 19     int64                                 1                21.0
# 20  CHAR(32)  19c91ef95d509ea33eda93495c4d3481             32951.0
# 21  CHAR(32)  744dac408745240a2c2528fb1b6028f3              3095.0
# 25  CHAR(32)  51e827dc634ca855acba1d305c4649af             99440.0
# 30  CHAR(32)  2d5f45068d4eb8c87f3d9bfa87311a5c             98410.0
# 31  CHAR(32)  452f45581d396d07e3a7e9f4b4daf866             98673.0
# 37  CHAR(32)  6fa8b8abbb489a0abba6ad7b79c7ecd9             32951.0
# 46  CHAR(32)  891071be6ba827b591264c90c2ae8a63              3095.0
#
#    is_not_null is_unique is_primary_key is_foreign_key is_id
# 0         True      True           True          False  True
# 1         True     False          False           True  True
# 10        True      True           True          False  True
# 11        True      True           True          False  True
# 18        True     False          False           True  True
# 19        True     False          False           True  True
# 20        True     False          False           True  True
# 21        True     False          False           True  True
# 25        True     False          False           True  True
# 30        True     False          False           True  True
# 31        True     False          False           True  True
# 37        True      True           True          False  True
# 46        True      True           True          False  True
