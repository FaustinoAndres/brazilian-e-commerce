# %% [markdown]
# ### Initial exploratory analysis of the table set olist_order_items_dataset.csv

# %%
# Import libraries here
# Tool that allows us to import, better manage the data set
import pandas as pd
# Tool that helps us in the mathematical handling of data
import numpy as np
# Library that helps us in data visualization
import matplotlib.pyplot as plt
# Data visualization tool
import seaborn as sns
sns.set_theme(style="darkgrid")
sns.set(rc={'figure.figsize':(15,8.27)})

# %%
# Import data here
df = pd.read_csv("../../data/raw/olist_order_items_dataset.csv")

# %%
# The method is used to display the first rows of the dataframe
df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
# At this point we visualize the data of the last rows of the dataframe
df.tail()
# Out:
#                                 order_id  order_item_id  \
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 112645  4aa6014eceb682077f9dc4bffebc05b0  b8bc237ba3788b23da09c0f1f3a3288c
# 112646  32e07fd915822b0765e448c4dd74c828  f3c38ab652836d21de61fb8314b69182
# 112647  72a30483855e2eafc67aee5dc2560482  c3cfdc648177fdbbbb35635a37472c53
# 112648  9c422a519119dcad7575db5af1ba540e  2b3e4a2a3ea8e01938cabda2a3e5cc79
# 112649  350688d9dc1e75ff97be326363655e01  f7ccf836d21b2fb1de37564105216cc1
#
#         shipping_limit_date   price  freight_value
# 112645  2018-05-02 04:11:01  299.99          43.41
# 112646  2018-07-20 04:31:48  350.00          36.53
# ...

# %%
# Check the number of rows and columns of the dataframe
print(df.shape)
# Out:
# (112650, 7)

# %%
# Extensive information on my dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
df.dtypes
# Out:
# order_id                object
# order_item_id            int64
# product_id              object
# seller_id               object
# shipping_limit_date     object
# price                  float64
# freight_value          float64
# dtype: object

# %% [markdown]
# - It can be seen that we have several categorical or data columns of the object type, of which the columns 'order_id', 'product_id', 'seller_id', which refer to an identification id of said category in particular, we also have a data of type object that refers to date and time 'shipping_limit_date'.
# - Regarding the numeric data of the integer type, it refers to the 'order_item_id' column.
# - Finally, the float or decimal data refers to the 'price' and 'freight_value' columns, which makes a lot of sense for them to be decimal since it is given to a particular cost value representation.

# %%
df.describe()
# Out:
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000

# %% [markdown]
# - Regarding the data set whose values are numerical data, we can observe the 'order_item_id' column, in which it gives us the information that the minimum value is 1, having a maximum value of 21, giving us an average of 1,197.
# - Regarding the 'price' column, we can determine that the minimum value of prices with respect to this data set has the value of 0.85 and the maximum value of 6735.00, with an average of 120.65.
# - In addition, there is the 'freight_value' column, which indicates that the minimum value is 0.00 and its maximum value is 409.68, having an average of 19.99, which a priori indicates that some items or tuples cost 0 of the value of the freight, it can give us some valuable information for later analysis.

# %% [markdown]
# To broaden the panorama of information, we will also include the categorical data and take advantage of the describe(include='all') function, in order to have a greater amount of preliminary information on the data set.

# %%
df.describe(include='all')
# Out:
#                                 order_id  order_item_id  \
# count                             112650  112650.000000
# unique                             98666            NaN
# top     8272b63d03f5f79c56e9e4120aec44ef            NaN
# freq                                  21            NaN
# mean                                 NaN       1.197834
# std                                  NaN       0.705124
# min                                  NaN       1.000000
# 25%                                  NaN       1.000000
# 50%                                  NaN       1.000000
# 75%                                  NaN       1.000000
# max                                  NaN      21.000000
#
#                               product_id                         seller_id  \
# count                             112650                            112650
# unique                             32951                              3095
# ...

# %% [markdown]
# - Describing the panorama in which this data set is found, we can observe in the first instance the 'order_id' column in this column we can observe that of the 112,650 it has 98,666 unique data whose value is repeated the most in 21 opportunities.
# - Regarding the 'product_id' column, the unique data is 32951 whose most repeated data is 527 opportunities.
# - Now observing the 'seller_id' column, it can be said that within the data set it has 3095 unique data whose most repeated data does so in 2033 opportunities.
# - With regard to the 'shipping_limit_date' column, 93318 unique date values are observed whose value appears the most times within the data set on 21 occasions.

# %% [markdown]
# We will proceed to evaluate if within our data set we have null data or NaN and thus be able to know where.

# %%
df.isnull().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %% [markdown]
# With regard to having null data, it tells us that we do not have null data in our data set

# %%
df['order_id'].value_counts()
# Out:
# 8272b63d03f5f79c56e9e4120aec44ef    21
# 1b15974a0141d54e36626dca3fdc731a    20
# ab14fdcfbe524636d65ee38360e22ce8    20
# 9ef13efd6949e4573a18964dd1bbe7f5    15
# 428a2f660dc84138d969ccd69a0ab6d5    15
#                                     ..
# 5a0911d70c1f85d3bed0df1bf693a6dd     1
# 5a082b558a3798d3e36d93bfa8ca1eae     1
# 5a07264682e0b8fbb3f166edbbffc6e8     1
# 5a071192a28951b76774e5a760c8c9b7     1
# fffe41c64501cc87c801fd61db3f6244     1
# Name: order_id, Length: 98666, dtype: int64

# %%
df.groupby('order_id').count()
# Out:
#                                   order_item_id  product_id  seller_id  \
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214              1           1          1
# 00018f77f2f0320c557190d7a144bdd3              1           1          1
# 000229ec398224ef6ca0657da4fc703e              1           1          1
# 00024acbcdf0a6daa1e931b038114c75              1           1          1
# 00042b26cf59d7ce69dfabb4e55b4fd9              1           1          1
# ...                                         ...         ...        ...
# fffc94f6ce00a00581880bf54a75a037              1           1          1
# fffcd46ef2263f404302a634eb57f7eb              1           1          1
# fffce4705a9662cd70adb13d4a31832d              1           1          1
# fffe18544ffabc95dfada21779c9644f              1           1          1
# fffe41c64501cc87c801fd61db3f6244              1           1          1
#
#                                   shipping_limit_date  price  freight_value
# order_id
# ...

# %% [markdown]
# - The 5 values that are most repeated with respect to the 'order_id' column, do so 21 times, followed by two with 20 times and two with 15 times.

# %%
df['order_item_id'].value_counts()
# Out:
# 1     98666
# 2      9803
# 3      2287
# 4       965
# 5       460
# 6       256
# 7        58
# 8        36
# 9        28
# 10       25
# 11       17
# 12       13
# 13        8
# 14        7
# 15        5
# 16        3
# 17        3
# 18        3
# 19        3
# 20        3
# 21        1
# Name: order_item_id, dtype: int64

# %%
sns.countplot(y='order_item_id', data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='order_item_id'>

# %%
df.groupby('order_item_id').count()
# Out:
#                order_id  product_id  seller_id  shipping_limit_date  price  \
# order_item_id
# 1                 98666       98666      98666                98666  98666
# 2                  9803        9803       9803                 9803   9803
# 3                  2287        2287       2287                 2287   2287
# 4                   965         965        965                  965    965
# 5                   460         460        460                  460    460
# 6                   256         256        256                  256    256
# 7                    58          58         58                   58     58
# 8                    36          36         36                   36     36
# 9                    28          28         28                   28     28
# 10                   25          25         25                   25     25
# 11                   17          17         17                   17     17
# ...

# %%
df['order_item_id'].value_counts().sum()
# Out:
# 112650

# %% [markdown]
# - Within the 'order_item_id' column, it can be seen that there are 21 values, of which we can see that the first item appears in a much higher number than the other values.

# %%
df['product_id'].value_counts()
# Out:
# aca2eb7d00ea1a7b8ebd4e68314663af    527
# 99a4788cb24856965c36a24e339b6058    488
# 422879e10f46682990de24d770e7f83d    484
# 389d119b48cf3043d311335e499d9c6b    392
# 368c6c730842d78016ad823897a372db    388
#                                    ...
# dbc42f8ad8afd0147a5a46be630781f8      1
# 5d86ed92606c80a89e547cdba3946812      1
# 0b8750fa58fefe42cf03a9e2e4b8fce6      1
# a4758e74e2cdb74d0c4db83594ca14a3      1
# 350688d9dc1e75ff97be326363655e01      1
# Name: product_id, Length: 32951, dtype: int64

# %%
df.groupby('product_id').count()
# Out:
#                                   order_id  order_item_id  seller_id  \
# product_id
# 00066f42aeeb9f3007548bb9d3f33c38         1              1          1
# 00088930e925c41fd95ebfe695fd2655         1              1          1
# 0009406fd7479715e4bef61dd91f2462         1              1          1
# 000b8f95fcb9e0096488278317764d19         2              2          2
# 000d9be29b5207b54e86aa1b1ac54872         1              1          1
# ...                                    ...            ...        ...
# fff6177642830a9a94a0f2cba5e476d1         2              2          2
# fff81cc3158d2725c0655ab9ba0f712c         1              1          1
# fff9553ac224cec9d15d49f5a263411f         1              1          1
# fffdb2d0ec8d6a61f0a0a0db3f25b441         5              5          5
# fffe9eeff12fcbd74a2f2b007dde0c58         1              1          1
#
#                                   shipping_limit_date  price  freight_value
# product_id
# ...

# %% [markdown]
# - Within the 'product_id' column, it can be seen that the data that appears most within the data set does so to a greater extent than 527 opportunities, 488, 484, 392 and so on descending until reaching the unique values.

# %%
df['seller_id'].value_counts()
# Out:
# 6560211a19b47992c3666cc44a7e94c0    2033
# 4a3ca9315b744ce9f8e9374361493884    1987
# 1f50f920176fa81dab994f9023523100    1931
# cc419e0650a3c5ba77189a1882b7556a    1775
# da8622b14eb17ae2831f4ac5b9dab84a    1551
#                                     ...
# 400f221ab83037c0ea78f1267da9624d       1
# 1746c1ae87ac63d530c7c943d0ac42e2       1
# 16bdc8cefd0e32a6f0824d296c5ad14a       1
# ace601496e211a664100321f038f50af       1
# 13d95f0f6f73943d4ceffad0fc2cd32c       1
# Name: seller_id, Length: 3095, dtype: int64

# %%
df.groupby('seller_id').count()
# Out:
#                                   order_id  order_item_id  product_id  \
# seller_id
# 0015a82c2db000af6aaaf3ae2ecb0532         3              3           3
# 001cca7ae9ae17fb1caed9dfb1094831       239            239         239
# 001e6ad469a905060d959994f1b41e4f         1              1           1
# 002100f778ceb8431b7a1020ff7ab48f        55             55          55
# 003554e2dce176b5555353e4f3555ac8         1              1           1
# ...                                    ...            ...         ...
# ffcfefa19b08742c5d315f2791395ee5         1              1           1
# ffdd9f82b9a447f6f8d4b91554cc7dd3        20             20          20
# ffeee66ac5d5a62fe688b9d26f83f534        14             14          14
# fffd5413c0700ac820c7069d66d98c89        61             61          61
# ffff564a4f9085cd26170f4732393726        20             20          20
#
#                                   shipping_limit_date  price  freight_value
# seller_id
# ...

# %% [markdown]
# - Within this column we can see that we have 2033 data that are repeated the most followed by 1987, 1931, 1775, 1551 and so on progressively until we reach the unique values of the data set.

# %%
df['shipping_limit_date'].value_counts()
# Out:
# 2017-07-21 18:25:23    21
# 2018-03-01 02:50:48    21
# 2017-08-30 14:30:23    20
# 2017-02-03 21:44:49    15
# 2017-12-21 02:30:41    15
#                        ..
# 2017-10-02 03:56:18     1
# 2018-01-04 16:09:20     1
# 2018-04-25 16:55:28     1
# 2017-11-29 22:19:33     1
# 2018-06-12 17:10:13     1
# Name: shipping_limit_date, Length: 93318, dtype: int64

# %%
df.groupby('shipping_limit_date').count()
# Out:
#                      order_id  order_item_id  product_id  seller_id  price  \
# shipping_limit_date
# 2016-09-19 00:15:34         1              1           1          1      1
# 2016-09-19 23:11:33         3              3           3          3      3
# 2016-10-08 10:34:01         1              1           1          1      1
# 2016-10-08 10:45:33         1              1           1          1      1
# 2016-10-08 13:26:12         1              1           1          1      1
# ...                       ...            ...         ...        ...    ...
# 2018-09-14 12:30:56         1              1           1          1      1
# 2018-09-18 21:10:15         1              1           1          1      1
# 2020-02-03 20:23:22         1              1           1          1      1
# 2020-02-05 03:30:51         1              1           1          1      1
# 2020-04-09 22:35:08         2              2           2          2      2
#
#                      freight_value
# ...

# %% [markdown]
# - What the 'shipping_limit_date' column refers to, it refers to dates from which we can see that there are two dates that are the most repeated and they both do so in 21 opportunities followed by a date of 20 opportunities and then go the from 15 to progressively unique values.

# %%
df['price'].value_counts()
# Out:
# 59.90      2481
# 69.90      1987
# 49.90      1953
# 89.90      1548
# 99.90      1432
#            ...
# 1369.90       1
# 108.24        1
# 1224.99       1
# 24.52         1
# 736.00        1
# Name: price, Length: 5968, dtype: int64

# %%
df.groupby('price').count()
# Out:
#          order_id  order_item_id  product_id  seller_id  shipping_limit_date  \
# price
# 0.85            3              3           3          3                    3
# 1.20           20             20          20         20                   20
# 2.20            1              1           1          1                    1
# 2.29            1              1           1          1                    1
# 2.90            1              1           1          1                    1
# ...           ...            ...         ...        ...                  ...
# 4690.00         1              1           1          1                    1
# 4799.00         1              1           1          1                    1
# 6499.00         1              1           1          1                    1
# 6729.00         1              1           1          1                    1
# 6735.00         1              1           1          1                    1
#
#          freight_value
# price
# ...

# %% [markdown]
# - We can observe that the value that is repeated the most does 2481 opportunities and progressively other values until reaching the unique data.

# %%
df['freight_value'].value_counts()
# Out:
# 15.10    3707
# 7.78     2262
# 14.10    1875
# 11.85    1846
# 18.23    1575
#          ...
# 57.83       1
# 80.47       1
# 70.92       1
# 42.85       1
# 6.37        1
# Name: freight_value, Length: 6999, dtype: int64

# %%
df.groupby('freight_value').count()
# Out:
#                order_id  order_item_id  product_id  seller_id  \
# freight_value
# 0.00                383            383         383        383
# 0.01                  4              4           4          4
# 0.02                  3              3           3          3
# 0.03                 14             14          14         14
# 0.04                  4              4           4          4
# ...                 ...            ...         ...        ...
# 322.10                1              1           1          1
# 338.30                1              1           1          1
# 339.59                1              1           1          1
# 375.28                2              2           2          2
# 409.68                1              1           1          1
#
#                shipping_limit_date  price
# freight_value
# 0.00                           383    383
# 0.01                             4      4
# 0.02                             3      3
# ...

# %% [markdown]
# - It can be seen that the most repeated value is 15.10 with a frequency of 3707, so on with other values until reaching the unique values.
