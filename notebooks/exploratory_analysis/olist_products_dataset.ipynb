# %% [markdown]
# ### Initial exploratory analysis of the olist_products_dataset.csv table set

# %%
# Import libraries here
# Tool that allows us to import, better manage the data set
import pandas as pd
# Tool that helps us in the mathematical handling of data
import numpy as np
# Library that helps us in data visualization
import matplotlib.pyplot as plt
# Data visualization tool
import seaborn as sns
sns.set_theme(style="darkgrid")
sns.set(rc={'figure.figsize':(15,8.27)})

# %%
# Import data here
df = pd.read_csv("../../data/raw/olist_products_dataset.csv")

# %%
# The method is used to display the first rows of the dataframe
df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
# At this point we visualize the data of the last rows of the dataframe
df.tail()
# Out:
#                              product_id              product_category_name  \
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 32946                 45.0                        67.0                 2.0
# 32947                 41.0                       971.0                 1.0
# 32948                 50.0                       799.0                 1.0
# 32949                 60.0                       156.0                 2.0
# 32950                 58.0                       309.0                 1.0
#
# ...

# %%
# Check the number of rows and columns of the dataframe
print(df.shape)
# Out:
# (32951, 9)

# %%
# We extend information of my dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
df.dtypes
# Out:
# product_id                     object
# product_category_name          object
# product_name_lenght           float64
# product_description_lenght    float64
# product_photos_qty            float64
# product_weight_g              float64
# product_length_cm             float64
# product_height_cm             float64
# product_width_cm              float64
# dtype: object

# %% [markdown]
# - It is observed that in the data set we have 9 columns, of which we have two of type object and seven of type float.
# - The column 'product_id' refers to the identification of the product for this reason it is a categorical value that is presented to us in this data set.
# - The column 'product_category_name' has categorical information that refers to the categories of the product as expressed by its name, for this reason it fits with the characteristic of the data type.
# - With regard to numeric columns with float or decimal values such as 'product_name_length', 'product_description_length', 'product_photos_qty', 'product_weight_g', 'product_length_cm', 'product_height_cm', ''product_width_cm' are values that refer to measures for that reason it must correspond effectively with numerical information.

# %%
df.describe()
# Out:
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         32341.000000                32341.000000        32341.000000
# mean             48.476949                  771.495285            2.188986
# std              10.245741                  635.115225            1.736766
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  339.000000            1.000000
# 50%              51.000000                  595.000000            1.000000
# 75%              57.000000                  972.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# std         4282.038731          16.914458          13.637554
# ...

# %% [markdown]
# - Regarding the 'product_name_length' column, we can see that the minimum value is 5.00 in addition to its maximum value of 76.00 with an average of 48.47.
# - Regarding the 'product_description_length' column, we can see that the minimum value is 4.00 in addition to its maximum value of 3992.00 with an average of 771.49.
# - Regarding the 'product_photos_qty' column, we can see that the minimum value is 1.00 in addition to its maximum value of 20.00 with an average of 2.18.
# - Regarding the 'product_weight_g' column, we can see that the minimum value is 0.00 in addition to its maximum value of 40425.00 with an average of 2276.47.
# - Regarding the column 'product_length_cm' we can see that the minimum value is 7.00 in addition to its maximum value of 105.00 with an average of 30.81.
# - Regarding the 'product_height_cm' column, we can see that the minimum value is 2.00 in addition to its maximum value of 105.00 with an average of 16.93.
# - Regarding the 'product_width_cm' column, we can see that the minimum value is 6.00 in addition to its maximum value of 118.00 with an average of 23.19.

# %% [markdown]
# To broaden the panorama of information, we will also include the categorical data and take advantage of the describe(include='all') function, in order to have a greater amount of preliminary information on the data set.

# %%
df.describe(include='all')
# Out:
#                               product_id product_category_name  \
# count                              32951                 32341
# unique                             32951                    73
# top     1e9e8ef04dbcff4541ed26657ea517e5       cama_mesa_banho
# freq                                   1                  3029
# mean                                 NaN                   NaN
# std                                  NaN                   NaN
# min                                  NaN                   NaN
# 25%                                  NaN                   NaN
# 50%                                  NaN                   NaN
# 75%                                  NaN                   NaN
# max                                  NaN                   NaN
#
#         product_name_lenght  product_description_lenght  product_photos_qty  \
# count          32341.000000                32341.000000        32341.000000
# ...

# %% [markdown]
# - Regarding the 'product_id' column, we observe that it has 32,951 records as well as unique values, which makes us identify the records effectively.
# - The 'product_category_name' column has 32341 records, which is slightly less than the number of rows, which is 32341, which makes it possible to deduce that it has some NaN data, but for them it will be corroborated later, we can also determine that it has 73 unique values where the top value is 'bed_table_banho' which has a frequency of occurrence within the dataset of 3029 times.

# %% [markdown]
# We will proceed to evaluate if within our data set we have null data or NaN and thus be able to know where.

# %%
df.isnull().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %% [markdown]
# - As the hypothesis had already been generated in some columns, here we can corroborate that in four of them they have 610 NaN data and in another four they have 2 records with NaN data, respectively.

# %%
df['product_id'].value_counts()
# Out:
# 1e9e8ef04dbcff4541ed26657ea517e5    1
# d05cc9afc85771f597cf4bc9d8f12546    1
# 71b7afd92c42feab780d5ea512fc7348    1
# 5c5f3e091101bea69642eb3dd145b17d    1
# 16d47089f9bc7f16de16cc4bd3b9dd49    1
#                                    ..
# c154987c6780d1a2b579aae00e53485f    1
# 1a6c9da4039deae58c2b769f049ae121    1
# 4cb35e544a1de008f37e069f172f964e    1
# b34b2c889f5b26963569cf421254e121    1
# 106392145fca363410d287a815be6de4    1
# Name: product_id, Length: 32951, dtype: int64

# %%
df.groupby('product_id').count()
# Out:
#                                   product_category_name  product_name_lenght  \
# product_id
# 00066f42aeeb9f3007548bb9d3f33c38                      1                    1
# 00088930e925c41fd95ebfe695fd2655                      1                    1
# 0009406fd7479715e4bef61dd91f2462                      1                    1
# 000b8f95fcb9e0096488278317764d19                      1                    1
# 000d9be29b5207b54e86aa1b1ac54872                      1                    1
# ...                                                 ...                  ...
# fff6177642830a9a94a0f2cba5e476d1                      1                    1
# fff81cc3158d2725c0655ab9ba0f712c                      1                    1
# fff9553ac224cec9d15d49f5a263411f                      1                    1
# fffdb2d0ec8d6a61f0a0a0db3f25b441                      1                    1
# fffe9eeff12fcbd74a2f2b007dde0c58                      1                    1
#
# ...

# %% [markdown]
# - We can see in the 'product_id' column, being pure unique data we will not have data groups by values.

# %%
df['product_category_name'].value_counts()
# Out:
# cama_mesa_banho                  3029
# esporte_lazer                    2867
# moveis_decoracao                 2657
# beleza_saude                     2444
# utilidades_domesticas            2335
#                                  ...
# fashion_roupa_infanto_juvenil       5
# casa_conforto_2                     5
# pc_gamer                            3
# seguros_e_servicos                  2
# cds_dvds_musicais                   1
# Name: product_category_name, Length: 73, dtype: int64

# %%
df.groupby('product_category_name').count()
# Out:
#                            product_id  product_name_lenght  \
# product_category_name
# agro_industria_e_comercio          74                   74
# alimentos                          82                   82
# alimentos_bebidas                 104                  104
# artes                              55                   55
# artes_e_artesanato                 19                   19
# ...                               ...                  ...
# sinalizacao_e_seguranca            93                   93
# tablets_impressao_imagem            9                    9
# telefonia                        1134                 1134
# telefonia_fixa                    116                  116
# utilidades_domesticas            2335                 2335
#
#                            product_description_lenght  product_photos_qty  \
# product_category_name
# agro_industria_e_comercio                          74                  74
# ...

# %% [markdown]
# - We can observe that within the data set we have in the 'product_category_name' column a greater number of categories 'cama_mesa_banho', 'esporte_lazer', 'moveis_decoracao', 'beleza_saude' and 'utilidades_domesticas' being the 5 with the highest number of records within the data set.

# %%
df['product_name_lenght'].value_counts()
# Out:
# 60.0    2182
# 59.0    2025
# 58.0    1887
# 57.0    1719
# 55.0    1683
#         ...
# 66.0       1
# 72.0       1
# 67.0       1
# 76.0       1
# 6.0        1
# Name: product_name_lenght, Length: 66, dtype: int64

# %%
df.groupby('product_name_lenght').count()
# Out:
#                      product_id  product_category_name  \
# product_name_lenght
# 5.0                           2                      2
# 6.0                           1                      1
# 7.0                           2                      2
# 8.0                           2                      2
# 9.0                           8                      8
# ...                         ...                    ...
# 67.0                          1                      1
# 68.0                          1                      1
# 69.0                          1                      1
# 72.0                          1                      1
# 76.0                          1                      1
#
#                      product_description_lenght  product_photos_qty  \
# product_name_lenght
# 5.0                                           2                   2
# 6.0                                           1                   1
# ...

# %% [markdown]
# - Within the column 'product_name_length' we can see that the value that is repeated the most is 60.0 with a quantity of 2182 and thus the measurements progressively change until they reach those of a single value within the data set.

# %%
df['product_description_lenght'].value_counts()
# Out:
# 404.0     94
# 729.0     86
# 651.0     66
# 703.0     66
# 236.0     65
#           ..
# 2795.0     1
# 2308.0     1
# 3698.0     1
# 3522.0     1
# 2207.0     1
# Name: product_description_lenght, Length: 2960, dtype: int64

# %%
df.groupby('product_description_lenght').count()
# Out:
#                             product_id  product_category_name  \
# product_description_lenght
# 4.0                                  5                      5
# 8.0                                  1                      1
# 15.0                                 1                      1
# 20.0                                 1                      1
# 23.0                                 1                      1
# ...                                ...                    ...
# 3963.0                               1                      1
# 3976.0                               1                      1
# 3985.0                               1                      1
# 3988.0                               1                      1
# 3992.0                               1                      1
#
#                             product_name_lenght  product_photos_qty  \
# product_description_lenght
# 4.0                                           5                   5
# ...

# %% [markdown]
# - In the column 'product_description_length' we have measurements of 404.0 like the one most frequently with 94 appearances and they generate different values that tend to appear in various records until reaching unique data.

# %%
df['product_photos_qty'].value_counts()
# Out:
# 1.0     16489
# 2.0      6263
# 3.0      3860
# 4.0      2428
# 5.0      1484
# 6.0       968
# 7.0       343
# 8.0       192
# 9.0       105
# 10.0       95
# 11.0       46
# 12.0       35
# 13.0        9
# 15.0        8
# 17.0        7
# 14.0        5
# 18.0        2
# 20.0        1
# 19.0        1
# Name: product_photos_qty, dtype: int64

# %%
df.groupby('product_photos_qty').count()
# Out:
#                     product_id  product_category_name  product_name_lenght  \
# product_photos_qty
# 1.0                      16489                  16489                16489
# 2.0                       6263                   6263                 6263
# 3.0                       3860                   3860                 3860
# 4.0                       2428                   2428                 2428
# 5.0                       1484                   1484                 1484
# 6.0                        968                    968                  968
# 7.0                        343                    343                  343
# 8.0                        192                    192                  192
# 9.0                        105                    105                  105
# 10.0                        95                     95                   95
# 11.0                        46                     46                   46
# ...

# %%
sns.countplot(y='product_photos_qty', data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='product_photos_qty'>

# %% [markdown]
# - In the 'product_photos_qty' column you can see that there are 19 options, among which they range from one photo to 20 photos, with 1 being the one that is repeated the most with respect to the other amounts.

# %%
df['product_weight_g'].value_counts()
# Out:
# 200.0     2084
# 300.0     1561
# 150.0     1259
# 400.0     1206
# 100.0     1188
#           ...
# 6075.0       1
# 822.0        1
# 631.0        1
# 2925.0       1
# 1920.0       1
# Name: product_weight_g, Length: 2204, dtype: int64

# %%
df.groupby('product_weight_g').count()
# Out:
#                   product_id  product_category_name  product_name_lenght  \
# product_weight_g
# 0.0                        4                      4                    4
# 2.0                        5                      5                    5
# 25.0                       1                      1                    1
# 50.0                     312                    310                  310
# 53.0                       1                      1                    1
# ...                      ...                    ...                  ...
# 29700.0                    2                      2                    2
# 29750.0                    1                      1                    1
# 29800.0                    1                      1                    1
# 30000.0                  143                    142                  142
# 40425.0                    1                      1                    1
#
#                   product_description_lenght  product_photos_qty  \
# ...

# %% [markdown]
# - It can be seen that within the 'product_weight_g' column there are quantities that are repeated the most, which are 200.0, 300.0, 150.0, 400.0 and 100.0, being the 5 that appear the most within the data set, passing to the values with unique data.

# %%
df['product_length_cm'].value_counts()
# Out:
# 16.0    5520
# 20.0    2816
# 30.0    2029
# 18.0    1502
# 25.0    1387
#         ...
# 96.0       4
# 10.0       3
# 8.0        2
# 9.0        2
# 7.0        1
# Name: product_length_cm, Length: 99, dtype: int64

# %%
df.groupby('product_length_cm').count()
# Out:
#                    product_id  product_category_name  product_name_lenght  \
# product_length_cm
# 7.0                         1                      1                    1
# 8.0                         2                      2                    2
# 9.0                         2                      2                    2
# 10.0                        3                      3                    3
# 11.0                       16                     16                   16
# ...                       ...                    ...                  ...
# 101.0                      18                     18                   18
# 102.0                      19                     19                   19
# 103.0                       9                      9                    9
# 104.0                      19                     19                   19
# 105.0                     149                    148                  148
#
# ...

# %% [markdown]
# - Regarding the 'product_length_cm' column, it can be seen that the most repeated measurement is 16.0, which appears in the records 5520 times within the data set, as well as other measurement values that are more common until reaching those of lower frequency and 7.0 being a unique value.

# %%
df['product_height_cm'].value_counts()
# Out:
# 10.0    2548
# 15.0    2022
# 20.0    1991
# 16.0    1595
# 11.0    1551
#         ...
# 98.0       2
# 97.0       2
# 99.0       1
# 89.0       1
# 94.0       1
# Name: product_height_cm, Length: 102, dtype: int64

# %%
df.groupby('product_height_cm').count()
# Out:
#                    product_id  product_category_name  product_name_lenght  \
# product_height_cm
# 2.0                      1357                   1277                 1277
# 3.0                       888                    874                  874
# 4.0                      1176                   1150                 1150
# 5.0                      1529                   1494                 1494
# 6.0                      1138                   1115                 1115
# ...                       ...                    ...                  ...
# 100.0                      15                     15                   15
# 102.0                       8                      8                    8
# 103.0                       4                      4                    4
# 104.0                       5                      5                    5
# 105.0                      24                     24                   24
#
# ...

# %% [markdown]
# - It can be seen that the 'product_height_cm' column has 2548 records of the data that is most repeated, which is 10.0, being the most common measurement, until reaching the less frequent ones, having some with unique values.

# %%
df['product_width_cm'].value_counts()
# Out:
# 11.0     3718
# 20.0     3053
# 16.0     2808
# 15.0     2393
# 30.0     1786
#          ...
# 103.0       1
# 86.0        1
# 98.0        1
# 87.0        1
# 104.0       1
# Name: product_width_cm, Length: 95, dtype: int64

# %%
df.groupby('product_width_cm').count()
# Out:
#                   product_id  product_category_name  product_name_lenght  \
# product_width_cm
# 6.0                        2                      2                    2
# 7.0                        4                      4                    4
# 8.0                        9                      9                    9
# 9.0                       15                     15                   15
# 10.0                      23                     23                   23
# ...                      ...                    ...                  ...
# 102.0                      2                      2                    2
# 103.0                      1                      1                    1
# 104.0                      1                      1                    1
# 105.0                      5                      5                    5
# 118.0                      1                      1                    1
#
#                   product_description_lenght  product_photos_qty  \
# ...

# %% [markdown]
# - The 'product_width_cm' column shows us the value that is repeated the most, which is 11.0, which does so by appearing within the data set 3718 times, in this way the most frequent ones are observed until reaching unique values.
