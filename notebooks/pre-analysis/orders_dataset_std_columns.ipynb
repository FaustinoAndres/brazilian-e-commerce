# %% [markdown]
# ## Preprocessing of file olist_orders_dataset.csv
#
# ## Initial Column Description
#
# This file has the problem that it does not have the same number of columns in all rows, there are rows with 10 columns and others with 9.
# A cleanup is performed by reading the file flat with the `open()` method. The transformed file is saved in data/pre_interim/orders_dataset_std_columns.csv'.

# %%
import pandas as pd

# %%
with open('../../data/pre_interim/orders_dataset.csv') as f:
    lines = f.readlines()

new_file = list()

new_file.append(lines[0])

for line in lines[1:]:
    #print(len(line.split(',')))
    l = line.split(',')
    if len(l) == 10:
        l.pop(2)
        new_file.append(','.join(l))
    else:
        new_file.append(line)

with open('../../data/pre_interim/orders_dataset_std_columns.csv', 'w') as f:
    for line in new_file:
        f.write(line)

# %%
df = pd.read_csv('../../data/pre_interim/orders_dataset_std_columns.csv')
df.head(150)
# Out:
#       ID  order_id                       customer_id order_status  \
# 0      1         1  0a8556ac6be836b46b3e89920d59291c    delivered
# 1      2         2  f2c7fc58a9de810828715166c672f10a    delivered
# 2      3         3  25b14b69de0b6e184ae6fe2755e478f9    delivered
# 3      4         4  7a5d8efaaa1081f800628c30d2b0728f    delivered
# 4      5         5  15fd6fb8f8312dbb4674e4518d6fa3b3    delivered
# ..   ...       ...                               ...          ...
# 145  146       146  55d6fe64c9ff321e925f284f7e0d69d8    delivered
# 146  147       147  165aeeded3ae717287fc0fc25a2ccf99    delivered
# 147  148       148  6de980369453bc98c75da669412a0e85    delivered
# 148  149       149  a996449b1a83201ba86b95b20cfed295    delivered
# 149  150       150  d50a8dc7e28e47e8119560e53b1c7deb    delivered
#
#     order_purchase_timestamp order_approved_at order_delivered_carrier_date  \
# 0           25/04/2018 22:01  25/04/2018 22:15              2/05/2018 15:20
# ...
